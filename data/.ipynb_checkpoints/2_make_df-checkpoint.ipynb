# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("allwords.json")

# %%
langs = ['en', 'es']

# %%
en_pronouns = {'I': 1, 'you': 2, 'he/she': 3, 'we': 4, 'they': 6}
es_pronouns = {'yo': 1, 'tú': 2, 'él/ella/Ud.': 3, 'nosotros': 4, 'vosotros': 5, 'ellos/ellas/Uds.': 6}

# %%
es_paradigms = set(['infinitive'])
for words in df['translations']:
    for translation in words:
        if 'spanConj' in translation:
            for conj in translation['spanConj']:
                es_paradigms.add(conj['paradigm'])
                
en_paradigms = set(['infinitive'])
for words in df['engConj']:
    for conj in words:
        en_paradigms.add(conj['paradigm'])

# %%
data = pd.DataFrame(columns=pd.MultiIndex.from_product([langs, es_paradigms, list(en_pronouns.values())]))

# %%
data
# Out:
# Empty DataFrame
# Columns: [(en, presentPerfect, 1), (en, presentPerfect, 2), (en, presentPerfect, 3), (en, presentPerfect, 4), (en, presentPerfect, 6), (en, conditionalContinuous, 1), (en, conditionalContinuous, 2), (en, conditionalContinuous, 3), (en, conditionalContinuous, 4), (en, conditionalContinuous, 6), (en, conditionalIndicative, 1), (en, conditionalIndicative, 2), (en, conditionalIndicative, 3), (en, conditionalIndicative, 4), (en, conditionalIndicative, 6), (en, imperfectContinuous, 1), (en, imperfectContinuous, 2), (en, imperfectContinuous, 3), (en, imperfectContinuous, 4), (en, imperfectContinuous, 6), (en, imperfectSubjunctive, 1), (en, imperfectSubjunctive, 2), (en, imperfectSubjunctive, 3), (en, imperfectSubjunctive, 4), (en, imperfectSubjunctive, 6), (en, presentIndicative, 1), (en, presentIndicative, 2), (en, presentIndicative, 3), (en, presentIndicative, 4), (en, presentIndicative, 6), (en, presentSubjunctive, 1), (en, presentSubjunctive, 2), (en, presentSubjunctive, 3), (en, presentSubjunctive, 4), (en, presentSubjunctive, 6), (en, futureIndicative, 1), (en, futureIndicative, 2), (en, futureIndicative, 3), (en, futureIndicative, 4), (en, futureIndicative, 6), (en, futureSubjunctive, 1), (en, futureSubjunctive, 2), (en, futureSubjunctive, 3), (en, futureSubjunctive, 4), (en, futureSubjunctive, 6), (en, pastPerfect, 1), (en, pastPerfect, 2), (en, pastPerfect, 3), (en, pastPerfect, 4), (en, pastPerfect, 6), (en, pastPerfectSubjunctive, 1), (en, pastPerfectSubjunctive, 2), (en, pastPerfectSubjunctive, 3), (en, pastPerfectSubjunctive, 4), (en, pastPerfectSubjunctive, 6), (en, presentPerfectSubjunctive, 1), (en, presentPerfectSubjunctive, 2), (en, presentPerfectSubjunctive, 3), (en, presentPerfectSubjunctive, 4), (en, presentPerfectSubjunctive, 6), (en, conditionalPerfect, 1), (en, conditionalPerfect, 2), (en, conditionalPerfect, 3), (en, conditionalPerfect, 4), (en, conditionalPerfect, 6), (en, negativeImperative, 1), (en, negativeImperative, 2), (en, negativeImperative, 3), (en, negativeImperative, 4), (en, negativeImperative, 6), (en, imperfectIndicative, 1), (en, imperfectIndicative, 2), (en, imperfectIndicative, 3), (en, imperfectIndicative, 4), (en, imperfectIndicative, 6), (en, preteritContinuous, 1), (en, preteritContinuous, 2), (en, preteritContinuous, 3), (en, preteritContinuous, 4), (en, preteritContinuous, 6), (en, futureContinuous, 1), (en, futureContinuous, 2), (en, futureContinuous, 3), (en, futureContinuous, 4), (en, futureContinuous, 6), (en, preteritIndicative, 1), (en, preteritIndicative, 2), (en, preteritIndicative, 3), (en, preteritIndicative, 4), (en, preteritIndicative, 6), (en, imperative, 1), (en, imperative, 2), (en, imperative, 3), (en, imperative, 4), (en, imperative, 6), (en, preteritPerfect, 1), (en, preteritPerfect, 2), (en, preteritPerfect, 3), (en, preteritPerfect, 4), (en, preteritPerfect, 6), ...]
# Index: []
#
# [0 rows x 230 columns]

# %%
data.columns
# Out:
# MultiIndex([('en',        'presentPerfect', 1),
#             ('en',        'presentPerfect', 2),
#             ('en',        'presentPerfect', 3),
#             ('en',        'presentPerfect', 4),
#             ('en',        'presentPerfect', 6),
#             ('en', 'conditionalContinuous', 1),
#             ('en', 'conditionalContinuous', 2),
#             ('en', 'conditionalContinuous', 3),
#             ('en', 'conditionalContinuous', 4),
#             ('en', 'conditionalContinuous', 6),
#             ...
#             ('es',         'futurePerfect', 1),
#             ('es',         'futurePerfect', 2),
#             ('es',         'futurePerfect', 3),
#             ('es',         'futurePerfect', 4),
#             ('es',         'futurePerfect', 6),
#             ('es',     'presentContinuous', 1),
#             ('es',     'presentContinuous', 2),
#             ('es',     'presentContinuous', 3),
#             ('es',     'presentContinuous', 4),
#             ('es',     'presentContinuous', 6)],
#            length=240)

# %%
for ind, row in df.iterrows():
    data_row = {}
    en_conj = row['engConj']
    for conj in en_conj:
        data_row[('en', conj['paradigm'], en_pronouns[conj['pronoun']])] = conj['word']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-4f1c5cf6205e> in <module>
#       3     en_conj = row['engConj']
#       4     for conj in en_conj:
# ----> 5         data_row[('en', conj['paradigm'], en_pronouns[conj['pronoun']])] = conj['word']
#
# KeyError: 'yo'

# %%
row
# Out:
# engWord                                                       has
# engConj         [{'pronoun': 'yo', 'person': '1st', 'number': ...
# translations    [{'word': 'have', 'lang': 'en', 'context': 'to...
# Name: 1, dtype: object

# %%
df['engConj'][0]
# Out:
# [{'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'has'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'I',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'he/she',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'we',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'they',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'has had'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'I',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'he/she',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'we',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'they',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'I',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'have'},
#  {'pronoun': 'he/she',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'we',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': "let's have"},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'have'},
#  {'pronoun': 'they',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'I',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': "don't have"},
#  {'pronoun': 'he/she',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'we',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': "let's not have"},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': "don't have"},
#  {'pronoun': 'they',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'am having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'is having'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'I',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'was having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'he/she',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'was having'},
#  {'pronoun': 'we',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'they',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'has been having'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'I',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'he/she',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'we',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'they',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'}]

# %%
df['engConj'][0]
# Out:
# [{'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'has'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'have'},
#  {'pronoun': 'I',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'he/she',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'we',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'they',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'had'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'will have'},
#  {'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'has had'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'have had'},
#  {'pronoun': 'I',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'he/she',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'we',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'they',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'had had'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'will have had'},
#  {'pronoun': 'I',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'have'},
#  {'pronoun': 'he/she',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'we',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': "let's have"},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'have'},
#  {'pronoun': 'they',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'I',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': "don't have"},
#  {'pronoun': 'he/she',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'we',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': "let's not have"},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': "don't have"},
#  {'pronoun': 'they',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'am having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'is having'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'are having'},
#  {'pronoun': 'I',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'was having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'he/she',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'was having'},
#  {'pronoun': 'we',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'they',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastContinuous',
#   'word': 'were having'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'will be having'},
#  {'pronoun': 'I',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'he/she',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'has been having'},
#  {'pronoun': 'we',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'they',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentPerfectContinuous',
#   'word': 'have been having'},
#  {'pronoun': 'I',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'he/she',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'we',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'they',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'pastPerfectContinuous',
#   'word': 'had been having'},
#  {'pronoun': 'I',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'he/she',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'we',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'you',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'},
#  {'pronoun': 'they',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futurePerfectContinuous',
#   'word': 'will have been having'}]

# %%
df['translations'][0][0]['spanConj']
# Out:
# [{'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tengo'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tienes'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tiene'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tenemos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tenéis'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tienen'},
#  {'pronoun': 'vos',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'presentIndicative',
#   'word': 'tenés'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuve'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuviste'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuvo'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuvimos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuvisteis'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuvieron'},
#  {'pronoun': 'vos',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'preteritIndicative',
#   'word': 'tuviste'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'tenía'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'tenías'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'tenía'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'teníamos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'teníais'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'tenían'},
#  {'pronoun': 'vos',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'imperfectIndicative',
#   'word': 'tenías'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendría'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendrías'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendría'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendríamos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendríais'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendrían'},
#  {'pronoun': 'vos',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'conditionalIndicative',
#   'word': 'tendrías'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendré'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendrás'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendrá'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendremos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendréis'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendrán'},
#  {'pronoun': 'vos',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'simp',
#   'paradigm': 'futureIndicative',
#   'word': 'tendrás'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tenga'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tengas'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tenga'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tengamos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tengáis'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tengan'},
#  {'pronoun': 'vos',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'presentSubjunctive',
#   'word': 'tengas'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuviera,tuviese'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuvieras,tuvieses'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuviera,tuviese'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuviéramos,tuviésemos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuvierais,tuvieseis'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuvieran,tuviesen'},
#  {'pronoun': 'vos',
#   'tense': 'imperfect',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'imperfectSubjunctive',
#   'word': 'tuvieras,tuvieses'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuviere'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuvieres'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuviere'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuviéremos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuviereis'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuvieren'},
#  {'pronoun': 'vos',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'simp',
#   'paradigm': 'futureSubjunctive',
#   'word': 'tuvieres'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': '-'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'ten'},
#  {'pronoun': 'Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'tenga'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'tengamos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'tened'},
#  {'pronoun': 'Uds.',
#   'person': '3rd',
#   'number': 'plr',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'tengan'},
#  {'pronoun': 'vos',
#   'tense': 'affirmative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'imperative',
#   'word': 'tené'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': '-'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': 'no tengas'},
#  {'pronoun': 'Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': 'no tenga'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': 'no tengamos'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': 'no tengáis'},
#  {'pronoun': 'Uds.',
#   'person': '3rd',
#   'number': 'plr',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': 'no tengan'},
#  {'pronoun': 'vos',
#   'tense': 'negative',
#   'mood': 'imp',
#   'form': 'simp',
#   'paradigm': 'negativeImperative',
#   'word': 'no tengas'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'estoy teniendo'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'estás teniendo'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'está teniendo'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'estamos teniendo'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'estáis teniendo'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'están teniendo'},
#  {'pronoun': 'vos',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'presentContinuous',
#   'word': 'estás teniendo'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuve teniendo'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuviste teniendo'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuvo teniendo'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuvimos teniendo'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuvisteis teniendo'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuvieron teniendo'},
#  {'pronoun': 'vos',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'preteritContinuous',
#   'word': 'estuviste teniendo'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estaba teniendo'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estabas teniendo'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estaba teniendo'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estábamos teniendo'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estabais teniendo'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estaban teniendo'},
#  {'pronoun': 'vos',
#   'tense': 'imperfect',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'imperfectContinuous',
#   'word': 'estabas teniendo'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estaría teniendo'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estarías teniendo'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estaría teniendo'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estaríamos teniendo'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estaríais teniendo'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estarían teniendo'},
#  {'pronoun': 'vos',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'conditionalContinuous',
#   'word': 'estarías teniendo'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estaré teniendo'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estarás teniendo'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estará teniendo'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estaremos teniendo'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estaréis teniendo'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estarán teniendo'},
#  {'pronoun': 'vos',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'prog',
#   'paradigm': 'futureContinuous',
#   'word': 'estarás teniendo'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'he tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'has tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'ha tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'hemos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'habéis tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'han tenido'},
#  {'pronoun': 'vos',
#   'tense': 'present',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'presentPerfect',
#   'word': 'has tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hube tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hubiste tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hubo tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hubimos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hubisteis tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hubieron tenido'},
#  {'pronoun': 'vos',
#   'tense': 'preterite',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'preteritPerfect',
#   'word': 'hubiste tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'había tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'habías tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'había tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'habíamos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'habíais tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'habían tenido'},
#  {'pronoun': 'vos',
#   'tense': 'past',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'pastPerfect',
#   'word': 'habías tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habría tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habrías tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habría tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habríamos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habríais tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habrían tenido'},
#  {'pronoun': 'vos',
#   'tense': 'conditional',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'conditionalPerfect',
#   'word': 'habrías tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habré tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habrás tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habrá tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habremos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habréis tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habrán tenido'},
#  {'pronoun': 'vos',
#   'tense': 'future',
#   'mood': 'ind',
#   'form': 'perf',
#   'paradigm': 'futurePerfect',
#   'word': 'habrás tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'haya tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'hayas tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'haya tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'hayamos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'hayáis tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'hayan tenido'},
#  {'pronoun': 'vos',
#   'tense': 'present',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'presentPerfectSubjunctive',
#   'word': 'hayas tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubiera tenido,hubiese tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubieras tenido,hubieses tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubiera tenido,hubiese tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubiéramos tenido,hubiésemos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubierais tenido,hubieseis tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubieran tenido,hubiesen tenido'},
#  {'pronoun': 'vos',
#   'tense': 'past',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'pastPerfectSubjunctive',
#   'word': 'hubieras tenido,hubieses tenido'},
#  {'pronoun': 'yo',
#   'person': '1st',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubiere tenido'},
#  {'pronoun': 'tú',
#   'person': '2nd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubieres tenido'},
#  {'pronoun': 'él/ella/Ud.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubiere tenido'},
#  {'pronoun': 'nosotros',
#   'person': '1st',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubiéremos tenido'},
#  {'pronoun': 'vosotros',
#   'person': '2nd',
#   'number': 'plr',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubiereis tenido'},
#  {'pronoun': 'ellos/ellas/Uds.',
#   'person': '3rd',
#   'number': 'sig',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubieren tenido'},
#  {'pronoun': 'vos',
#   'tense': 'future',
#   'mood': 'sub',
#   'form': 'perf',
#   'paradigm': 'futurePerfectSubjunctive',
#   'word': 'hubieres tenido'}]
